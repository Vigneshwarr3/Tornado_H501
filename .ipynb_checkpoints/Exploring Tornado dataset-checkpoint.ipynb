# %% [markdown]
# # Group 4 - Standup Report

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.transforms import Bbox

# %%
df = pd.read_csv('1950-2023_all_tornadoes.csv')

# %%
#importing the dataset and storing it in a variable df
df
# Out:
#            om    yr  mo  dy        date      time  tz  st  stf  stn  ...  \
# 0         192  1950  10   1  1950-10-01  21:00:00   3  OK   40   23  ...
# 1         193  1950  10   9  1950-10-09  02:15:00   3  NC   37    9  ...
# 2         195  1950  11  20  1950-11-20  02:20:00   3  KY   21    1  ...
# 3         196  1950  11  20  1950-11-20  04:00:00   3  KY   21    2  ...
# 4         197  1950  11  20  1950-11-20  07:30:00   3  MS   28   14  ...
# ...       ...   ...  ..  ..         ...       ...  ..  ..  ...  ...  ...
# 71393  623328  2023   9  26  2023-09-26  15:05:00   3  FL   12    0  ...
# 71394  623329  2023   9  28  2023-09-28  13:40:00   3  OH   39    0  ...
# 71395  623330  2023   9  29  2023-09-29  18:48:00   3  MN   27    0  ...
# 71396  623304  2023   9   2  2023-09-02  10:11:00   3  LA   22    0  ...
# 71397  623305  2023   9   9  2023-09-09  15:30:00   3  AZ    4    0  ...
#
#          len  wid  ns  sn  sg   f1  f2  f3  f4  fc
# ...

# %%
# "om" tells us count of tornado during the year. what is the maximum no of tornado in the column "om"?
max(df['om'])
# Out:
# 623401

# %% [markdown]
# 623401 is a really large number. It says us that 1707 tornadoes has affected in a day in that year. If we consider in a hour, it is around 71 tornadoes. This is highly unlikely.

# %%
df[['om', 'yr']].groupby('yr').sum().reset_index().head()
# Out:
#      yr      om
# 0  1950   20410
# 1  1951   33938
# 2  1952   29960
# 3  1953   92246
# 4  1954  156504

# %% [markdown]
# Below I am considering each row as an tornado entry and counting how many entries are there for each year using groupby function.

# %%
df1 = df[['om', 'yr']].groupby('yr').count().reset_index()

# %%
df1.head()
# Out:
#      yr   om
# 0  1950  206
# 1  1951  261
# 2  1952  246
# 3  1953  442
# 4  1954  570

# %% [markdown]
# This is far better than the previous result, as it says 1950 has 206 tornado occurences.

# %%
#No of tornadoes affected in each year from 1950 to 2023
sns.lineplot(data = df1, x = 'yr', y = 'om')
# Out:
# <Axes: xlabel='yr', ylabel='om'>

# %%
#No of tornadoes affected in each year from 2007 to 2023
sns.lineplot(data = df1[df1['yr'] > 2007], x = 'yr', y = 'om')
# Out:
# <Axes: xlabel='yr', ylabel='om'>

# %%
#lets see how many unique time zones are there in the column 'tz' (tz is time zone as mentioned in description)
df['tz'].unique()
# Out:
# array([3, 0, 6, 9])

# %%
#getting all states under the time zome 3
df[(df['tz'] == 3)]['st'].unique()
# Out:
# array(['OK', 'NC', 'KY', 'MS', 'PA', 'IL', 'AR', 'MO', 'TX', 'OH', 'LA',
#        'TN', 'FL', 'AL', 'SC', 'KS', 'WY', 'NE', 'GA', 'IA', 'SD', 'ND',
#        'MN', 'WI', 'NM', 'CT', 'IN', 'CO', 'MD', 'WV', 'VA', 'MA', 'OR',
#        'CA', 'NJ', 'MI', 'NH', 'AZ', 'NY', 'MT', 'VT', 'UT', 'ME', 'ID',
#        'WA', 'DE', 'HI', 'AK', 'PR', 'NV', 'RI', 'DC', 'VI'], dtype=object)

# %%
#getting all states under the time zome 0
df[(df['tz'] == 0)]['st'].unique()
# Out:
# array(['MA', 'OK', 'IN', 'TX', 'IL', 'SD'], dtype=object)

# %%
df[(df['tz'] == 0)]['st'].unique()
# Out:
# array(['MA', 'OK', 'IN', 'TX', 'IL', 'SD'], dtype=object)

# %%
#getting all states under the time zome 6
df[(df['tz'] == 6)]['st'].unique()
# Out:
# array(['SD', 'NM', 'MT', 'WY'], dtype=object)

# %%
#getting all states under the time zome 9
df[(df['tz'] == 9)]['st'].unique()
# Out:
# array(['LA'], dtype=object)

# %% [markdown]
# The documentation only mentioned about the time zones 9(GST) and 3(CST). By getting the above States of each time zone, it is clear that, all the states in the time zone 0 and 6 is already present in the time zone 3.
# <br>
# <br>
# So, we can replace the time zones 0 and 6 with 3.

# %%
df.isnull().sum()
# Out:
# om       0
# yr       0
# mo       0
# dy       0
# date     0
# time     0
# tz       0
# st       0
# stf      0
# stn      0
# mag      0
# inj      0
# fat      0
# loss     0
# closs    0
# slat     0
# slon     0
# elat     0
# elon     0
# len      0
# wid      0
# ns       0
# sn       0
# sg       0
# f1       0
# f2       0
# f3       0
# f4       0
# fc       0
# dtype: int64

# %%
df.head()
# Out:
#     om    yr  mo  dy        date      time  tz  st  stf  stn  ...   len  wid  \
# 0  192  1950  10   1  1950-10-01  21:00:00   3  OK   40   23  ...  15.8   10
# 1  193  1950  10   9  1950-10-09  02:15:00   3  NC   37    9  ...   2.0  880
# 2  195  1950  11  20  1950-11-20  02:20:00   3  KY   21    1  ...   0.1   10
# 3  196  1950  11  20  1950-11-20  04:00:00   3  KY   21    2  ...   0.1   10
# 4  197  1950  11  20  1950-11-20  07:30:00   3  MS   28   14  ...   2.0   37
#
#    ns  sn  sg   f1  f2  f3  f4  fc
# 0   1   1   1   25   0   0   0   0
# 1   1   1   1   47   0   0   0   0
# 2   1   1   1  177   0   0   0   0
# 3   1   1   1  209   0   0   0   0
# 4   1   1   1  101   0   0   0   0
#
# [5 rows x 29 columns]

# %%
df.columns
# Out:
# Index(['om', 'yr', 'mo', 'dy', 'date', 'time', 'tz', 'st', 'stf', 'stn', 'mag',
#        'inj', 'fat', 'loss', 'closs', 'slat', 'slon', 'elat', 'elon', 'len',
#        'wid', 'ns', 'sn', 'sg', 'f1', 'f2', 'f3', 'f4', 'fc'],
#       dtype='object')

# %%
d = {}
for column in df.columns:
    x = input(f"{column} : ")
    d[column] = x
# Out:
# om :  Tornado_number
# yr :  Year
# mo :  Month
# dy :  Day
# date :  Date
# time :  Time
# tz :  Time_zone
# st :  State
# stf :  State_FIPS
# stn :  State_no
# mag :  Wind_speed
# inj :  Injuries
# fat :  Fatalities
# loss :  Property_loss
# closs :  Crop_loss
# slat :  Start_lat
# slon :  Start_lon
# elat :  End_lat
# elon :  End_lon
# len :  Length
# wid :  Width
# ns :  States_affected
# sn :  State_number
# sg :  Segment_no
# f1 :  Country1_FIPS
# f2 :  Country2_FIPS
# f3 :  Country3_FIPS
# f4 :  Country4_FIPS
# fc :  Estimated_Fscale

# %%
df.rename(columns = d , inplace = True)

# %%
df.describe()
# Out:
#        Tornado_number          Year         Month           Day     Time_zone  \
# count    71398.000000  71398.000000  71398.000000  71398.000000  71398.000000
# mean    123921.574162   1992.500140      5.945713     15.938752      3.000924
# std     235622.304082     19.876577      2.457315      8.770595      0.071003
# min          1.000000   1950.000000      1.000000      1.000000      0.000000
# 25%        289.000000   1976.000000      4.000000      8.000000      3.000000
# 50%        602.000000   1995.000000      6.000000     16.000000      3.000000
# 75%       1212.000000   2009.000000      7.000000     24.000000      3.000000
# max     623401.000000   2023.000000     12.000000     31.000000      9.000000
#
#          State_FIPS      State_no    Wind_speed      Injuries    Fatalities  \
# count  71398.000000  71398.000000  71398.000000  71398.000000  71398.000000
# mean      29.111586     22.557691      0.657862      1.575506      0.103014
# ...

# %%
df1 = df[['Year', 'Month_name', 'Month']].value_counts().reset_index().sort_values(['Year', 'Month']).reset_index()

# %%
df1.drop(['index', 'Month'], axis = 1 , inplace = True)

# %%
df1
# Out:
#      Year Month_name  count
# 0    1950    January      9
# 1    1950   February     21
# 2    1950      March     23
# 3    1950      April     15
# 4    1950        May     61
# ..    ...        ...    ...
# 878  2023     August    147
# 879  2023  September     27
# 880  2023    October     32
# 881  2023   November     18
# 882  2023   December     25
#
# [883 rows x 3 columns]

# %%
df['Date'] = pd.to_datetime(df)

# %%
df['Month_name'] = df['Date'].dt.month_name()

# %%
df.head()
# Out:
#    Tornado_number  Year  Month  Day       Date      Time  Time_zone State  \
# 0             192  1950     10    1 1950-10-01  21:00:00          3    OK
# 1             193  1950     10    9 1950-10-09  02:15:00          3    NC
# 2             195  1950     11   20 1950-11-20  02:20:00          3    KY
# 3             196  1950     11   20 1950-11-20  04:00:00          3    KY
# 4             197  1950     11   20 1950-11-20  07:30:00          3    MS
#
#    State_FIPS  State_no  ...  Width  States_affected  State_number  \
# 0          40        23  ...     10                1             1
# 1          37         9  ...    880                1             1
# 2          21         1  ...     10                1             1
# 3          21         2  ...     10                1             1
# 4          28        14  ...     37                1             1
#
#    Segment_no  Country1_FIPS  Country2_FIPS  Country3_FIPS  Country4_FIPS  \
# ...

# %%
sns.lineplot(df1[df1['Year'] > 2018], x = 'Month_name', y = 'count', hue = 'Year',palette='viridis')
# Out:
# <Axes: xlabel='Month_name', ylabel='count'>

# %%
sns.histplot(df[df['Year']<=1991].sort_values('Month'), x = 'Month_name')
plt.xticks(rotation=45) 
plt.title("Months of Peak Tornado Occurrence (1950-1991)")
plt.xlabel('Month')
plt.ylabel('Count of Tornadoes')

plt.show

plt.savefig('peak_tornado_occurence.jpg', bbox_inches = 'tight', dpi = 200)

# %%
sns.histplot(df[(df['State'] =='IN')].sort_values('Month'), x = 'Month_name')
plt.xticks(rotation=45) 
plt.title("Months of Peak Tornado Occurrence")
plt.xlabel('Month')
plt.ylabel('Count of Tornadoes over 7 decades')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
# Out:
#    Tornado_number  Year  Month  Day       Date      Time  Time_zone State  \
# 0             192  1950     10    1 1950-10-01  21:00:00          3    OK
# 1             193  1950     10    9 1950-10-09  02:15:00          3    NC
# 2             195  1950     11   20 1950-11-20  02:20:00          3    KY
# 3             196  1950     11   20 1950-11-20  04:00:00          3    KY
# 4             197  1950     11   20 1950-11-20  07:30:00          3    MS
#
#    State_FIPS  State_no  ...  Width  States_affected  State_number  \
# 0          40        23  ...     10                1             1
# 1          37         9  ...    880                1             1
# 2          21         1  ...     10                1             1
# 3          21         2  ...     10                1             1
# 4          28        14  ...     37                1             1
#
#    Segment_no  Country1_FIPS  Country2_FIPS  Country3_FIPS  Country4_FIPS  \
# ...

# %%
sns.histplot(df.sort_values('Month'), x = 'State')
plt.xticks(rotation=45) 
plt.title("Months of Peak Tornado Occurrence")
plt.xlabel('Month')
plt.ylabel('Count of Tornadoes over 7 decades')

plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
sns.barplot(df['State'].value_counts().head().reset_index(), x= 'State', y = 'count')
plt.title("Top 5 States with Tornado occurences")
plt.xlabel('State')
plt.ylabel('Number of tornadoes')

plt.savefig('top 5 states.jpg', dpi = 200)
plt.show()

# %%
df['Wind_speed'].value_counts()
# Out:
# Wind_speed
#  0    32450
#  1    24166
#  2    10085
#  3     2839
# -9     1031
#  4      739
#  5       88
# Name: count, dtype: int64

# %%
df[]
# Out:
#        Tornado_number  Year  Month  Day       Date      Time  Time_zone State  \
# 0                 192  1950     10    1 1950-10-01  21:00:00          3    OK
# 1                 193  1950     10    9 1950-10-09  02:15:00          3    NC
# 2                 195  1950     11   20 1950-11-20  02:20:00          3    KY
# 3                 196  1950     11   20 1950-11-20  04:00:00          3    KY
# 4                 197  1950     11   20 1950-11-20  07:30:00          3    MS
# ...               ...   ...    ...  ...        ...       ...        ...   ...
# 71393          623328  2023      9   26 2023-09-26  15:05:00          3    FL
# 71394          623329  2023      9   28 2023-09-28  13:40:00          3    OH
# 71395          623330  2023      9   29 2023-09-29  18:48:00          3    MN
# 71396          623304  2023      9    2 2023-09-02  10:11:00          3    LA
# 71397          623305  2023      9    9 2023-09-09  15:30:00          3    AZ
#
# ...

# %%
df['Tornado_number'].value_counts()
# Out:
# Tornado_number
# 124       71
# 157       69
# 64        69
# 90        68
# 80        68
#           ..
# 576971     1
# 565118     1
# 585176     1
# 585177     1
# 623305     1
# Name: count, Length: 17331, dtype: int64

# %%
df[df['Year']==1950]
# Out:
# 0      192
# 1      193
# 2      195
# 3      196
# 4      197
#       ...
# 201    181
# 202    182
# 203    189
# 204    190
# 205    191
# Name: Tornado_number, Length: 206, dtype: int64

# %%
df.head()
# Out:
#     om    yr  mo  dy        date      time  tz  st  stf  stn  ...   len  wid  \
# 0  192  1950  10   1  1950-10-01  21:00:00   3  OK   40   23  ...  15.8   10
# 1  193  1950  10   9  1950-10-09  02:15:00   3  NC   37    9  ...   2.0  880
# 2  195  1950  11  20  1950-11-20  02:20:00   3  KY   21    1  ...   0.1   10
# 3  196  1950  11  20  1950-11-20  04:00:00   3  KY   21    2  ...   0.1   10
# 4  197  1950  11  20  1950-11-20  07:30:00   3  MS   28   14  ...   2.0   37
#
#    ns  sn  sg   f1  f2  f3  f4  fc
# 0   1   1   1   25   0   0   0   0
# 1   1   1   1   47   0   0   0   0
# 2   1   1   1  177   0   0   0   0
# 3   1   1   1  209   0   0   0   0
# 4   1   1   1  101   0   0   0   0
#
# [5 rows x 29 columns]

# %%
df[(df['yr'] == 1950) & (df['st'] == 'IL')].sort_values('date')
# Out:
#       om    yr  mo  dy        date      time  tz  st  stf  stn  ...   len  \
# 16     1  1950   1   3  1950-01-03  11:10:00   3  IL   17    1  ...   3.3
# 17     2  1950   1   3  1950-01-03  11:55:00   3  IL   17    2  ...   3.6
# 12     6  1950   1  25  1950-01-25  21:00:00   3  IL   17    3  ...   0.1
# 61    48  1950   3  27  1950-03-27  16:30:00   3  IL   17    4  ...   3.0
# 139  135  1950   6  13  1950-06-13  03:00:00   3  IL   17    5  ...   0.1
# 171  165  1950   7  16  1950-07-16  22:15:00   3  IL   17    6  ...   1.0
# 6    198  1950  12   2  1950-12-02  15:00:00   3  IL   17    7  ...  18.8
# 7    199  1950  12   2  1950-12-02  16:00:00   3  IL   17    8  ...  18.0
# 9    201  1950  12   2  1950-12-02  17:30:00   3  IL   17    9  ...   9.6
#
#      wid  ns  sn  sg   f1   f2  f3  f4  fc
# 16   100   2   1   2  119    0   0   0   0
# 17   130   1   1   1  135    0   0   0   0
# 12   100   1   1   1   91    0   0   0   0
# 61    50   1   1   1  113    0   0   0   0
# ...

# %%
df[['yr', 'st']].value_counts().reset_index().sort_values(['yr', 'st']).reset_index()
# Out:
#       index    yr  st  count
# 0      2699  1950  AL      2
# 1      1616  1950  AR     12
# 2      2597  1950  CO      2
# 3      2595  1950  CT      2
# 4      2055  1950  FL      6
# ...     ...   ...  ..    ...
# 3182   2875  2023  VT      1
# 3183   2420  2023  WA      3
# 3184   1110  2023  WI     21
# 3185   2880  2023  WV      1
# 3186   1119  2023  WY     21
#
# [3187 rows x 4 columns]

# %%
df_ = df.groupby(['yr', 'st'])['om'].count().reset_index()

# %%
df_.rename(columns = {'yr':'year', 'st': 'state', 'om': 'count of tornadoes'})
# Out:
#       year state  count of tornadoes
# 0     1950    AL                   2
# 1     1950    AR                  12
# 2     1950    CO                   2
# 3     1950    CT                   2
# 4     1950    FL                   6
# ...    ...   ...                 ...
# 3182  2023    VT                   1
# 3183  2023    WA                   3
# 3184  2023    WI                  21
# 3185  2023    WV                   1
# 3186  2023    WY                  21
#
# [3187 rows x 3 columns]

# %%
df_
# Out:
#         yr  st  om
# 0     1950  AL   2
# 1     1950  AR  12
# 2     1950  CO   2
# 3     1950  CT   2
# 4     1950  FL   6
# ...    ...  ..  ..
# 3182  2023  VT   1
# 3183  2023  WA   3
# 3184  2023  WI  21
# 3185  2023  WV   1
# 3186  2023  WY  21
#
# [3187 rows x 3 columns]

# %%
df[(df['yr'] == 1950) & (df['st'] == 'AR')].sort_values('date')
# Out:
#       om    yr  mo  dy        date      time  tz  st  stf  stn  ...   len  \
# 10     4  1950   1  13  1950-01-13  05:25:00   3  AR    5    1  ...   0.6
# 30    19  1950   2  12  1950-02-12  12:30:00   3  AR    5    2  ...   0.1
# 35    23  1950   2  12  1950-02-12  15:00:00   3  AR    5    3  ...   5.7
# 44    33  1950   3  26  1950-03-26  19:30:00   3  AR    5    4  ...  17.4
# 45    34  1950   3  26  1950-03-26  19:31:00   3  AR    5    5  ...   5.7
# 46    35  1950   3  26  1950-03-26  20:30:00   3  AR    5    6  ...  10.4
# 47    36  1950   3  26  1950-03-26  21:15:00   3  AR    5    7  ...  14.9
# 48    37  1950   3  26  1950-03-26  23:30:00   3  AR    5    8  ...   5.4
# 74    49  1950   4   2  1950-04-02  15:30:00   3  AR    5    9  ...   2.5
# 76    51  1950   4   2  1950-04-02  18:00:00   3  AR    5   10  ...   0.8
# 191  184  1950   8  24  1950-08-24  03:45:00   3  AR    5   11  ...   3.6
# 8    200  1950  12   2  1950-12-02  16:25:00   3  AR    5   12  ...   7.8
#
# ...

# %%
sns.lineplot(df_[df_['st']=='TX'], x = 'yr', y = 'om')
# Out:
# <Axes: xlabel='yr', ylabel='om'>

# %%
tornadoes_each_yr = df[['Tornado_number', 'Year', 'State']].groupby(['Year', 'State']).nunique('Tornado_number').reset_index()

# %%
sns.lineplot(tornadoes_each_yr, x = 'Year', y = 'Tornado_number')
plt.show()

# %% [raw]
# df[['om', 'yr']].groupby('yr').count().reset_index()

# %%
tornadoes_each_yr['om_old']=df_old['om']

# %%
tornadoes_each_yr['diff']= tornadoes_each_yr['om_old'] - tornadoes_each_yr['om']

# %%
tornadoes_each_yr.head(6)
# Out:
#      yr   om  om_old  diff
# 0  1950  201     206     5
# 1  1951  260     261     1
# 2  1952  240     246     6
# 3  1953  421     442    21
# 4  1954  550     570    20
# 5  1955  591     604    13

# %%
df.columns
# Out:
# Index(['om', 'yr', 'mo', 'dy', 'date', 'time', 'tz', 'st', 'stf', 'stn', 'mag',
#        'inj', 'fat', 'loss', 'closs', 'slat', 'slon', 'elat', 'elon', 'len',
#        'wid', 'ns', 'sn', 'sg', 'f1', 'f2', 'f3', 'f4', 'fc'],
#       dtype='object')

# %%
df['mag'].value_counts()
# Out:
# mag
#  0    32450
#  1    24166
#  2    10085
#  3     2839
# -9     1031
#  4      739
#  5       88
# Name: count, dtype: int64

# %%
df_old = df[['om', 'yr']].groupby('yr').count().reset_index()
sns.lineplot(df_old, x = 'yr', y = 'om')
plt.show()

# %%
df.head()
# Out:
#     om    yr  mo  dy        date      time  tz  st  stf  stn  ...   len  wid  \
# 0  192  1950  10   1  1950-10-01  21:00:00   3  OK   40   23  ...  15.8   10
# 1  193  1950  10   9  1950-10-09  02:15:00   3  NC   37    9  ...   2.0  880
# 2  195  1950  11  20  1950-11-20  02:20:00   3  KY   21    1  ...   0.1   10
# 3  196  1950  11  20  1950-11-20  04:00:00   3  KY   21    2  ...   0.1   10
# 4  197  1950  11  20  1950-11-20  07:30:00   3  MS   28   14  ...   2.0   37
#
#    ns  sn  sg   f1  f2  f3  f4  fc
# 0   1   1   1   25   0   0   0   0
# 1   1   1   1   47   0   0   0   0
# 2   1   1   1  177   0   0   0   0
# 3   1   1   1  209   0   0   0   0
# 4   1   1   1  101   0   0   0   0
#
# [5 rows x 29 columns]

# %%
df['ns'].value_counts()
# Out:
# ns
# 1    69524
# 2     1824
# 3       49
# 0        1
# Name: count, dtype: int64

# %%
df[(df['om'] == 192) & (df['yr'] == 1950)]
# Out:
#     om    yr  mo  dy        date      time  tz  st  stf  stn  ...   len  wid  \
# 0  192  1950  10   1  1950-10-01  21:00:00   3  OK   40   23  ...  15.8   10
#
#    ns  sn  sg  f1  f2  f3  f4  fc
# 0   1   1   1  25   0   0   0   0
#
# [1 rows x 29 columns]

# %%
d = {'om': 'Tornado_number',
 'yr': 'Year',
 'mo': 'Month',
 'dy': 'Day',
 'date': 'Date',
 'time': 'Time',
 'tz': 'Time_zone',
 'st': 'State',
 'stf': 'State_FIPS',
 'stn': 'Stn_no',
 'mag': 'Wind_speed',
 'inj': 'Injuries',
 'fat': 'Fatalities',
 'loss': 'Property_loss',
 'closs': 'Crop_loss',
 'slat': 'Start_lat',
 'slon': 'Start_lon',
 'elat': 'End_lat',
 'elon': 'End_lon',
 'len': 'Length',
 'wid': 'Width',
 'ns': 'States_affected',
 'sn': 'State_number',
 'sg': 'Segment_no',
 'f1': 'Country1_FIPS',
 'f2': 'Country2_FIPS',
 'f3': 'Country3_FIPS',
 'f4': 'Country4_FIPS',
 'fc': 'Estimated_Fscale'}

# %%
df.rename(columns = d, inplace = True)

# %%
df.head()
# Out:
#    Tornado_number  Year  Month  Day        Date      Time  Time_zone State  \
# 0             192  1950     10    1  1950-10-01  21:00:00          3    OK
# 1             193  1950     10    9  1950-10-09  02:15:00          3    NC
# 2             195  1950     11   20  1950-11-20  02:20:00          3    KY
# 3             196  1950     11   20  1950-11-20  04:00:00          3    KY
# 4             197  1950     11   20  1950-11-20  07:30:00          3    MS
#
#    State_FIPS  Stn_no  ...  Length  Width  States_affected  State_number  \
# 0          40      23  ...    15.8     10                1             1
# 1          37       9  ...     2.0    880                1             1
# 2          21       1  ...     0.1     10                1             1
# 3          21       2  ...     0.1     10                1             1
# 4          28      14  ...     2.0     37                1             1
#
# ...

# %%
tornadoes_each_yr
# Out:
#       Year State  Tornado_number
# 0     1950    AL               2
# 1     1950    AR              12
# 2     1950    CO               2
# 3     1950    CT               2
# 4     1950    FL               6
# ...    ...   ...             ...
# 3182  2023    VT               1
# 3183  2023    WA               3
# 3184  2023    WI              21
# 3185  2023    WV               1
# 3186  2023    WY              21
#
# [3187 rows x 3 columns]

# %%
fatal_loss = df[df['State_number'] == 1]\
    [['Year','State', 'Fatalities', 'Tornado_number']]\
    .groupby(['Year', 'State'])\
    .aggregate({"Fatalities":"sum", "Tornado_number":'nunique'}).reset_index()

# %%
fatal_loss[fatal_loss['Year'] == 2023].sort_values('Fatalities', ascending = False)
# Out:
#       Year State  Fatalities  Tornado_number
# 3161  2023    MS          24              63
# 3179  2023    TN          17              40
# 3140  2023    AL           9              73
# 3180  2023    TX           8              78
# 3152  2023    IN           6              54
# 3160  2023    MO           5              21
# 3141  2023    AR           4              30
# 3148  2023    GA           4              56
# 3151  2023    IL           4             121
# 3172  2023    OK           2              76
# 3158  2023    MI           2              14
# 3146  2023    DE           1               3
# 3174  2023    PA           0              24
# 3170  2023    NY           0              10
# 3171  2023    OH           0              60
# 3173  2023    OR           0               4
# 3178  2023    SD           0              18
# 3175  2023    PR           0               3
# 3176  2023    RI           0               3
# 3177  2023    SC           0              17
# ...
